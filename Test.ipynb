# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
radius = np.random.randint(1, 5, size=(100, ))
angle = np.random.randn(100, ) * np.pi
polar = np.stack((radius, angle), axis=1)
print(polar.shape)
plt.scatter(polar[:, 0], polar[:, 1]);
# Out:
# (100, 2)

# %%
 np.sqrt((cartesian ** 2).sum(axis=1))
# Out:
# array([2., 3., 1., 3., 4., 4., 3., 4., 4., 2., 4., 4., 3., 4., 3., 4., 3.,
#        2., 2., 2., 2., 3., 4., 2., 2., 3., 3., 1., 3., 3., 3., 2., 3., 4.,
#        1., 3., 1., 4., 1., 2., 4., 3., 2., 2., 3., 3., 3., 4., 2., 3., 3.,
#        4., 2., 3., 3., 4., 2., 1., 2., 3., 4., 3., 1., 2., 1., 4., 4., 1.,
#        1., 3., 2., 3., 4., 2., 4., 1., 3., 4., 2., 3., 2., 1., 3., 3., 1.,
#        2., 3., 1., 3., 2., 3., 4., 3., 4., 3., 4., 3., 1., 4., 2.])

# %%
cartesian = np.stack((polar[:, 0] * np.cos(polar[:, 1]), polar[:, 0] * np.sin(polar[:, 1])), axis=1)
print(cartesian.shape)
plt.scatter(cartesian[:, 0], cartesian[:, 1]);
# Out:
# (100, 2)

# %%
g = nx.Graph()
g.add_nodes_from([(1, {"feature": 3}), (2, {"feature": 12}), (4, {"feature": 0}), (6, {"feature": 11})])

# %%
nx.get_node_attributes(g, "feature")
# Out:
# {1: 3, 2: 12, 4: 0, 6: 11}

# %%
np.array(list(nx.get_node_attributes(g, "feature").values()))
# Out:
# array([ 3, 12,  0, 11])

# %%
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np

# %%
def say_my_name(name):
    """
    Print the current widget value in short sentence
    """
    print(f'My name is {name}')
     
widgets.interact(say_my_name, name=["Jim", "Emma", "Bond"]);
# Out:
# interactive(children=(Dropdown(description='name', options=('Jim', 'Emma', 'Bond'), value='Jim'), Output()), _…

# %%
widgets.__version__
# Out:
# '8.0.6'
